# %%
# !pip install modin
# Out:
# zsh:1: no matches found: modin[ray]

# %%
import pandas as pd

# %%
# %%time
df = pd.read_csv("/Users/oliver/Desktop/Road to DS in 2024/DS2024/CSGO Data/csgo_test.csv")
# Out:
# CPU times: user 15.8 s, sys: 2.49 s, total: 18.3 s
# Wall time: 18.6 s

# %%
df.head()
# Out:
#                       file  round   tick   seconds att_team vic_team  \
# 0  esea_match_13818366.dem      1  21257  165.8779   Team 2   Team 1
# 1  esea_match_13818366.dem      1  21653  168.9752   Team 1   Team 2
# 2  esea_match_13818366.dem      1  21717  169.4758   Team 1   Team 2
# 3  esea_match_13818366.dem      1  21937  171.1965   Team 1   Team 2
# 4  esea_match_13818366.dem      1  22229  173.4804   Team 1   Team 2
#
#            att_side          vic_side  hp_dmg  arm_dmg  ...     wp wp_type  \
# 0         Terrorist  CounterTerrorist      20        0  ...  Glock  Pistol
# 1  CounterTerrorist         Terrorist     100        0  ...    USP  Pistol
# 2  CounterTerrorist         Terrorist     100        0  ...    USP  Pistol
# 3  CounterTerrorist         Terrorist      14        6  ...    USP  Pistol
# 4  CounterTerrorist         Terrorist     100        0  ...    USP  Pistol
#
#               att_id att_rank             vic_id  vic_rank  att_pos_x  \
# ...

# %%
# %%time
df.groupby('att_team').count()
# Out:
# CPU times: user 2.2 s, sys: 386 ms, total: 2.59 s
# Wall time: 2.61 s
#                          file    round     tick  seconds  vic_team  att_side  \
# att_team
# --to be determined--      647      647      647      647       647       647
# ALTERNATE aTTaX           791      791      791      791       791       791
# BOOT-dS Letou             610      610      610      610       610       610
# Cerus eSports             338      338      338      338       338       338
# Chiefs                    823      823      823      823       823       823
# Dynasty                   710      710      710      710       710       710
# FlashGaming               660      660      660      660       660       660
# Grayhound                 759      759      759      759       759       759
# Ground Zero               720      720      720      720       720       720
# Guerrilla Tactics         350      350      350      350       350       350
# ...

# %%
### modin does not work for my laptop

# %%
# Out:
# 2024-07-18 23:09:47,857 - distributed.core - ERROR - Exception while handling op scatter
# Traceback (most recent call last):
#   File "/Users/oliver/anaconda3/lib/python3.11/site-packages/distributed/core.py", line 924, in _handle_comm
#     result = await result
#              ^^^^^^^^^^^^
#   File "/Users/oliver/anaconda3/lib/python3.11/site-packages/distributed/scheduler.py", line 5859, in scatter
#     raise TimeoutError("No valid workers found")
# TimeoutError: No valid workers found
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File <timed exec>:1
#
# File ~/anaconda3/lib/python3.11/site-packages/modin/utils.py:591, in expanduser_path_arg.<locals>.decorator.<locals>.wrapped(*args, **kw)
#     589     elif isinstance(patharg, Path):
#     590         params.arguments[argname] = patharg.expanduser()
# --> 591     return func(*params.args, **params.kwargs)
# ...
