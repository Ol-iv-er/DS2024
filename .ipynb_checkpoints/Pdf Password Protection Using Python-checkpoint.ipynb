# %%
#!pip install PyPDF2

# %%
from PyPDF2 import PdfReader, PdfWriter

# %%
### Open the current PDF

file_pdf=PdfReader('pdf_example.pdf')

## Object for PDF writer
out_pdf= PdfWriter()

# %%
file_pdf # we see that is a object of PyPDF2 type

# %%
len(file_pdf.pages) # see the length of the pdf
# Out:
# 30

# %%
type(file_pdf.pages) # we see that the pdf pages are stored a list of some kind
# Out:
# PyPDF2._page._VirtualList

# %%
type(out_pdf)
# Out:
# PyPDF2._writer.PdfWriter

# %%
type(file_pdf)
# Out:
# PyPDF2._reader.PdfReader

# %%
# out_pdf.add_blank_page(100,100)

# %%
type(out_pdf)
# Out:
# PyPDF2._writer.PdfWriter

# %%
## will need to trouble shoot as the tutorial is kinda old
for i in range(len(file_pdf.pages)):
    page_details=file_pdf.pages[i]
    ### adding pages to the output page
    out_pdf.add_page(page_details)
# Out:
# 30
# 30

# %%
password = 'oliverisrad2420913'

out_pdf.encrypt(password)

# %%
with open('encrypted_data.pdf', 'wb') as filename:
    out_pdf.write(filename)

# %%
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[46], line 2
#       1 encrpyted_file = open('encrypted_data.pdf', 'r')
# ----> 2 print(encrpyted_file.read())
#
# File <frozen codecs>:322, in decode(self, input, final)
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte

# %%
with open('pdf_example.pdf', 'r') as file:
    file.read()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[47], line 2
#       1 with open('pdf_example.pdf', 'r') as file:
# ----> 2     file.read()
#
# File <frozen codecs>:322, in decode(self, input, final)
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x9c in position 72: invalid start byte
