# %% [markdown]
# This is a snippet of the code from Pycharm on logging. Logging is useful as we can use it to find were errors occur in the code or program.

# %%
import logging

logging.basicConfig(filename='Logging.txt',
                    filemode='a',
                    format='%(asctime)s %(levelname)s-%(message)s',
                    datefmt='%Y-%m-%d %H:%M:%S')
"""
for i in range(0, 15):
    if(i % 2 == 0):
        logging.warning('Log Warning Message ({})'.format(i))
    elif(i%3==0):
        logging.warning('Log Critical Message ({})'.format(i))
    else:
        logging.warning("Log Error Message ({})".format(i))
"""

i=10
try:
    i = i/0
except:
    logging.error('Division by 0 error')
