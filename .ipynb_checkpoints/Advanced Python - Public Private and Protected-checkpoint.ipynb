# %% [markdown]
# ## Python OOPS - Public, Private, and Protected

# %%
class car():
    def __init__(self, engine_type, doors, windows):
        self.engine_type=engine_type
        self.doors=doors
        self.windows=windows
